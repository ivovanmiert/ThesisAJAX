# %%
import pandas as pd
import yaml
import csv
from itertools import combinations

# %%
def load_config(config_path):
    with open(config_path, 'r') as file:
        config = yaml.safe_load(file)
    return config

config = load_config('config.yaml')

# %%
csv_location = config['data_paths']['output_file_full_dataframe']
df = pd.read_csv(csv_location)

# %%
total_number_of_matches = len(df['match_id'].unique())
average_number_of_events_per_match = len(df)/ total_number_of_matches
average_number_of_events_per_match
# Out:
# 1680.9322033898304

# %% [markdown]
# Occurences of primary types:

# %%
unique_values_primary_type = df['primary_type'].value_counts()
unique_values_primary_type
# Out:
# primary_type
# pass                 246263
# duel                 118374
# touch                 38542
# interception          21952
# game_interruption     19496
# throw_in              11307
# free_kick              7886
# infraction             7387
# shot                   6588
# goal_kick              4612
# clearance              3071
# acceleration           2955
# corner                 2875
# shot_against           2482
# offside                 906
# goalkeeper_exit         705
# fairplay                347
# penalty                 106
# own_goal                 21
# Name: count, dtype: int64

# %% [markdown]
# First all uniques secondary types. Then the occurences of primary types in combination with the seperated secondary types

# %%
unique_secondary_types_separated = pd.Series([
    word.strip()
    for sublist in df['secondary_types'].dropna().str.split(',')
    for word in sublist
]).unique()
print(unique_secondary_types_separated)
print(len(unique_secondary_types_separated))
# Out:
# ['back_pass' 'short_or_medium_pass' 'lateral_pass' 'forward_pass'
#  'progressive_pass' 'loose_ball_duel' 'carry' 'long_pass'
#  'pass_to_final_third' 'opportunity' 'head_pass' 'recovery'
#  'under_pressure' 'ball_out' 'loss' 'hand_pass' 'foul_suffered'
#  'ground_duel' 'linkup_play' 'offensive_duel' 'defensive_duel' 'foul'
#  'dribble' 'aerial_duel' 'counterpressing_recovery' 'pass'
#  'deep_completion' 'touch_in_box' 'interception' 'sliding_tackle'
#  'progressive_run' 'smart_pass' 'cross' 'deep_completed_cross'
#  'pass_to_penalty_area' 'second_assist' 'assist' 'key_pass' 'shot_assist'
#  'goal' 'conceded_goal' 'dribbled_past_attempt' 'shot_after_throw_in'
#  'shot_block' 'free_kick_cross' 'save' 'save_with_reflex'
#  'shot_after_corner' 'yellow_card' 'cross_blocked' 'through_pass'
#  'free_kick_shot' 'shot' 'head_shot' 'whistle' 'shot_after_free_kick'
#  'acceleration' 'penalty_foul' 'penalty_goal' 'penalty_conceded_goal'
#  'third_assist' 'red_card' 'penalty_save']
# 63

# %%
pd.options.display.max_rows = 2800

# %%
# Initialize an empty list to store tuples of (primary_type, secondary_type)
expanded_rows = []

# Iterate over each row in the DataFrame
for index, row in df.dropna(subset=['secondary_types']).iterrows():
    primary = row['primary_type']
    secondary_list = row['secondary_types'].split(',')
    for secondary in secondary_list:
        expanded_rows.append((primary, secondary.strip()))

# Create a new DataFrame from the expanded rows
expanded_df = pd.DataFrame(expanded_rows, columns=['primary_type', 'secondary_type'])

# Get the counts of secondary types per primary type
counts_per_primary_type = expanded_df.groupby('primary_type')['secondary_type'].value_counts()

# Calculate the percentages
total_counts_per_primary = expanded_df.groupby('primary_type')['secondary_type'].count()
percentages = (counts_per_primary_type / total_counts_per_primary).reset_index(name='percentage')

# Combine counts and percentages
counts_per_primary_type = counts_per_primary_type.reset_index(name='count')
result = pd.merge(counts_per_primary_type, percentages, on=['primary_type', 'secondary_type'])

# %%
result
# Out:
#           primary_type            secondary_type   count  percentage
# 0         acceleration                     carry    2047    0.533351
# 1         acceleration           progressive_run    1744    0.454403
# 2         acceleration               linkup_play      45    0.011725
# 3         acceleration              third_assist       2    0.000521
# 4            clearance                      loss     973    0.458530
# 5            clearance                 head_pass     588    0.277097
# 6            clearance            under_pressure     341    0.160697
# 7            clearance                  recovery     146    0.068803
# 8            clearance  counterpressing_recovery      54    0.025448
# 9            clearance                     carry      19    0.008954
# 10           clearance               linkup_play       1    0.000471
# 11              corner               shot_assist     524    0.483841
# 12              corner                      loss     489    0.451524
# 13              corner                    assist      26    0.024007
# 14              corner               opportunity      15    0.013850
# 15              corner                     carry      11    0.010157
# 16              corner             second_assist      10    0.009234
# 17              corner              third_assist       5    0.004617
# 18              corner                      shot       2    0.001847
# 19              corner           progressive_run       1    0.000923
# 20                duel               ground_duel   78226    0.275748
# 21                duel            defensive_duel   39113    0.137874
# 22                duel            offensive_duel   39113    0.137874
# 23                duel               aerial_duel   20566    0.072495
# 24                duel           loose_ball_duel   19582    0.069027
# 25                duel                  recovery   17894    0.063077
# 26                duel                      loss   17106    0.060299
# 27                duel                   dribble   14614    0.051515
# 28                duel                     carry   10169    0.035846
# 29                duel  counterpressing_recovery    8530    0.030068
# 30                duel             foul_suffered    6545    0.023071
# 31                duel     dribbled_past_attempt    5996    0.021136
# 32                duel               linkup_play    2294    0.008086
# 33                duel            sliding_tackle    1677    0.005911
# 34                duel           progressive_run    1318    0.004646
# 35                duel              interception     880    0.003102
# 36                duel             second_assist      29    0.000102
# 37                duel                    assist      17    0.000060
# 38                duel               opportunity      10    0.000035
# 39                duel              third_assist       6    0.000021
# 40                duel                shot_block       2    0.000007
# 41            fairplay                      loss     153    0.927273
# 42            fairplay                 hand_pass       7    0.042424
# 43            fairplay                  recovery       3    0.018182
# 44            fairplay              interception       2    0.012121
# 45           free_kick           free_kick_cross     890    0.492257
# 46           free_kick            free_kick_shot     265    0.146571
# 47           free_kick                      shot     265    0.146571
# 48           free_kick               shot_assist     163    0.090155
# 49           free_kick               opportunity     148    0.081858
# 50           free_kick                     carry      37    0.020465
# 51           free_kick                    assist      19    0.010509
# 52           free_kick                      goal      12    0.006637
# 53           free_kick           progressive_run       3    0.001659
# 54           free_kick             second_assist       3    0.001659
# 55           free_kick              third_assist       3    0.001659
# 56   game_interruption                  ball_out   19045    0.976867
# 57   game_interruption                   whistle     451    0.023133
# 58           goal_kick                      loss     254    0.824675
# 59           goal_kick                     carry      53    0.172078
# 60           goal_kick             second_assist       1    0.003247
# 61     goalkeeper_exit                     carry      58    1.000000
# 62          infraction                      foul    7068    0.829772
# 63          infraction               yellow_card    1290    0.151444
# 64          infraction              penalty_foul     106    0.012444
# 65          infraction                  red_card      54    0.006340
# 66        interception                  recovery   11248    0.209421
# 67        interception                      pass    7522    0.140048
# 68        interception      short_or_medium_pass    6757    0.125805
# 69        interception                      loss    6157    0.114634
# 70        interception                 head_pass    4974    0.092608
# 71        interception              forward_pass    3910    0.072798
# 72        interception  counterpressing_recovery    3863    0.071923
# 73        interception                shot_block    1829    0.034053
# 74        interception          progressive_pass    1750    0.032582
# 75        interception              lateral_pass    1648    0.030683
# 76        interception                     carry     872    0.016235
# 77        interception                 long_pass     757    0.014094
# 78        interception       pass_to_final_third     753    0.014020
# 79        interception                 back_pass     658    0.012251
# 80        interception                 hand_pass     236    0.004394
# 81        interception              touch_in_box     193    0.003593
# 82        interception              acceleration     137    0.002551
# 83        interception           progressive_run     127    0.002365
# 84        interception      pass_to_penalty_area      99    0.001843
# 85        interception            under_pressure      67    0.001247
# 86        interception           deep_completion      41    0.000763
# 87        interception              through_pass      35    0.000652
# 88        interception               shot_assist      33    0.000614
# 89        interception                  key_pass      15    0.000279
# 90        interception                     cross       9    0.000168
# 91        interception                    assist       5    0.000093
# 92        interception                smart_pass       5    0.000093
# 93        interception             second_assist       4    0.000074
# 94        interception              third_assist       3    0.000056
# 95        interception             cross_blocked       2    0.000037
# 96        interception      deep_completed_cross       1    0.000019
# 97            own_goal              interception      16    0.363636
# 98            own_goal                  recovery      10    0.227273
# 99            own_goal                shot_block       5    0.113636
# 100           own_goal                      pass       3    0.068182
# 101           own_goal      short_or_medium_pass       3    0.068182
# 102           own_goal                 back_pass       2    0.045455
# 103           own_goal  counterpressing_recovery       2    0.045455
# 104           own_goal                 head_pass       2    0.045455
# 105           own_goal            under_pressure       1    0.022727
# 106               pass      short_or_medium_pass  213353    0.333383
# 107               pass              lateral_pass   94132    0.147090
# 108               pass              forward_pass   78835    0.123187
# 109               pass          progressive_pass   37744    0.058978
# 110               pass                 back_pass   36345    0.056792
# 111               pass                      loss   28135    0.043963
# 112               pass       pass_to_final_third   27661    0.043223
# 113               pass                 long_pass   24686    0.038574
# 114               pass                  recovery   16784    0.026226
# 115               pass            under_pressure   11959    0.018687
# 116               pass      pass_to_penalty_area   11034    0.017242
# 117               pass                 head_pass    9893    0.015459
# 118               pass                     cross    8627    0.013480
# 119               pass  counterpressing_recovery    8051    0.012580
# 120               pass               linkup_play    6370    0.009954
# 121               pass              touch_in_box    4440    0.006938
# 122               pass           deep_completion    4029    0.006296
# 123               pass               shot_assist    3474    0.005428
# 124               pass              through_pass    3139    0.004905
# 125               pass      deep_completed_cross    2954    0.004616
# 126               pass                  key_pass    1915    0.002992
# 127               pass                 hand_pass    1672    0.002613
# 128               pass                smart_pass    1576    0.002463
# 129               pass             cross_blocked    1462    0.002285
# 130               pass                     carry     931    0.001455
# 131               pass                    assist     361    0.000564
# 132               pass             second_assist     179    0.000280
# 133               pass              third_assist     129    0.000202
# 134               pass           progressive_run      94    0.000147
# 135            penalty                      shot     106    0.398496
# 136            penalty                      goal      80    0.300752
# 137            penalty              penalty_goal      80    0.300752
# 138               shot               opportunity    4841    0.390498
# 139               shot              touch_in_box    3941    0.317899
# 140               shot                 head_shot    1126    0.090828
# 141               shot         shot_after_corner     997    0.080423
# 142               shot                      goal     649    0.052351
# 143               shot       shot_after_throw_in     480    0.038719
# 144               shot      shot_after_free_kick     316    0.025490
# 145               shot              interception      38    0.003065
# 146               shot                shot_block       7    0.000565
# 147               shot                    assist       2    0.000161
# 148       shot_against                      save    1720    0.473568
# 149       shot_against          save_with_reflex    1055    0.290474
# 150       shot_against             conceded_goal     762    0.209802
# 151       shot_against     penalty_conceded_goal      80    0.022026
# 152       shot_against              penalty_save      15    0.004130
# 153           throw_in                      loss     976    0.861430
# 154           throw_in                     carry     101    0.089144
# 155           throw_in               shot_assist      46    0.040600
# 156           throw_in           progressive_run       6    0.005296
# 157           throw_in              third_assist       3    0.002648
# 158           throw_in             second_assist       1    0.000883
# 159              touch                     carry   26262    0.685817
# 160              touch           progressive_run    5908    0.154284
# 161              touch                      loss    3843    0.100358
# 162              touch              touch_in_box    1549    0.040451
# 163              touch            under_pressure     483    0.012613
# 164              touch               opportunity     238    0.006215
# 165              touch             second_assist       5    0.000131
# 166              touch              third_assist       4    0.000104
# 167              touch                    assist       1    0.000026

# %%
# Calculate conditional percentages
conditional_percentages = []

for primary_type in expanded_df['primary_type'].unique():
    subset_df = expanded_df[expanded_df['primary_type'] == primary_type]
    secondary_types = subset_df['secondary_type'].unique()
    
    for pair in combinations(secondary_types, 2):
        s1, s2 = pair
        s1_count = subset_df[subset_df['secondary_type'] == s1].shape[0]
        s2_count = subset_df[subset_df['secondary_type'] == s2].shape[0]
        common_count = subset_df[(subset_df['secondary_type'] == s1) & (subset_df['secondary_type'] == s2)].shape[0]
        
        if s1_count > 0:
            percentage = common_count / s1_count
            conditional_percentages.append((primary_type, s1, s2, percentage))
        
        if s2_count > 0 and s1 != s2:
            percentage = common_count / s2_count
            conditional_percentages.append((primary_type, s2, s1, percentage))

# Create DataFrame for conditional percentages
conditional_df = pd.DataFrame(conditional_percentages, columns=['primary_type', 'secondary_type1', 'secondary_type2', 'percentage'])

# %%
conditional_df
# Out:
#            primary_type           secondary_type1           secondary_type2  \
# 0                  pass                 back_pass      short_or_medium_pass
# 1                  pass      short_or_medium_pass                 back_pass
# 2                  pass                 back_pass              lateral_pass
# 3                  pass              lateral_pass                 back_pass
# 4                  pass                 back_pass              forward_pass
# 5                  pass              forward_pass                 back_pass
# 6                  pass                 back_pass          progressive_pass
# 7                  pass          progressive_pass                 back_pass
# 8                  pass                 back_pass                 long_pass
# 9                  pass                 long_pass                 back_pass
# 10                 pass                 back_pass       pass_to_final_third
# 11                 pass       pass_to_final_third                 back_pass
# 12                 pass                 back_pass                 hand_pass
# 13                 pass                 hand_pass                 back_pass
# 14                 pass                 back_pass                  recovery
# 15                 pass                  recovery                 back_pass
# 16                 pass                 back_pass            under_pressure
# 17                 pass            under_pressure                 back_pass
# 18                 pass                 back_pass                      loss
# 19                 pass                      loss                 back_pass
# 20                 pass                 back_pass                 head_pass
# 21                 pass                 head_pass                 back_pass
# 22                 pass                 back_pass  counterpressing_recovery
# 23                 pass  counterpressing_recovery                 back_pass
# 24                 pass                 back_pass               linkup_play
# 25                 pass               linkup_play                 back_pass
# 26                 pass                 back_pass           deep_completion
# 27                 pass           deep_completion                 back_pass
# 28                 pass                 back_pass              touch_in_box
# 29                 pass              touch_in_box                 back_pass
# 30                 pass                 back_pass                smart_pass
# 31                 pass                smart_pass                 back_pass
# 32                 pass                 back_pass                     cross
# 33                 pass                     cross                 back_pass
# 34                 pass                 back_pass      deep_completed_cross
# 35                 pass      deep_completed_cross                 back_pass
# 36                 pass                 back_pass      pass_to_penalty_area
# 37                 pass      pass_to_penalty_area                 back_pass
# 38                 pass                 back_pass             second_assist
# 39                 pass             second_assist                 back_pass
# 40                 pass                 back_pass                    assist
# 41                 pass                    assist                 back_pass
# 42                 pass                 back_pass                  key_pass
# 43                 pass                  key_pass                 back_pass
# 44                 pass                 back_pass               shot_assist
# 45                 pass               shot_assist                 back_pass
# 46                 pass                 back_pass             cross_blocked
# 47                 pass             cross_blocked                 back_pass
# 48                 pass                 back_pass              through_pass
# 49                 pass              through_pass                 back_pass
# 50                 pass                 back_pass                     carry
# 51                 pass                     carry                 back_pass
# 52                 pass                 back_pass              third_assist
# 53                 pass              third_assist                 back_pass
# 54                 pass                 back_pass           progressive_run
# 55                 pass           progressive_run                 back_pass
# 56                 pass      short_or_medium_pass              lateral_pass
# 57                 pass              lateral_pass      short_or_medium_pass
# 58                 pass      short_or_medium_pass              forward_pass
# 59                 pass              forward_pass      short_or_medium_pass
# 60                 pass      short_or_medium_pass          progressive_pass
# 61                 pass          progressive_pass      short_or_medium_pass
# 62                 pass      short_or_medium_pass                 long_pass
# 63                 pass                 long_pass      short_or_medium_pass
# 64                 pass      short_or_medium_pass       pass_to_final_third
# 65                 pass       pass_to_final_third      short_or_medium_pass
# 66                 pass      short_or_medium_pass                 hand_pass
# 67                 pass                 hand_pass      short_or_medium_pass
# 68                 pass      short_or_medium_pass                  recovery
# 69                 pass                  recovery      short_or_medium_pass
# 70                 pass      short_or_medium_pass            under_pressure
# 71                 pass            under_pressure      short_or_medium_pass
# 72                 pass      short_or_medium_pass                      loss
# 73                 pass                      loss      short_or_medium_pass
# 74                 pass      short_or_medium_pass                 head_pass
# 75                 pass                 head_pass      short_or_medium_pass
# 76                 pass      short_or_medium_pass  counterpressing_recovery
# 77                 pass  counterpressing_recovery      short_or_medium_pass
# 78                 pass      short_or_medium_pass               linkup_play
# 79                 pass               linkup_play      short_or_medium_pass
# 80                 pass      short_or_medium_pass           deep_completion
# 81                 pass           deep_completion      short_or_medium_pass
# 82                 pass      short_or_medium_pass              touch_in_box
# 83                 pass              touch_in_box      short_or_medium_pass
# 84                 pass      short_or_medium_pass                smart_pass
# 85                 pass                smart_pass      short_or_medium_pass
# 86                 pass      short_or_medium_pass                     cross
# 87                 pass                     cross      short_or_medium_pass
# 88                 pass      short_or_medium_pass      deep_completed_cross
# 89                 pass      deep_completed_cross      short_or_medium_pass
# 90                 pass      short_or_medium_pass      pass_to_penalty_area
# 91                 pass      pass_to_penalty_area      short_or_medium_pass
# 92                 pass      short_or_medium_pass             second_assist
# 93                 pass             second_assist      short_or_medium_pass
# 94                 pass      short_or_medium_pass                    assist
# 95                 pass                    assist      short_or_medium_pass
# 96                 pass      short_or_medium_pass                  key_pass
# 97                 pass                  key_pass      short_or_medium_pass
# 98                 pass      short_or_medium_pass               shot_assist
# 99                 pass               shot_assist      short_or_medium_pass
# 100                pass      short_or_medium_pass             cross_blocked
# 101                pass             cross_blocked      short_or_medium_pass
# 102                pass      short_or_medium_pass              through_pass
# 103                pass              through_pass      short_or_medium_pass
# 104                pass      short_or_medium_pass                     carry
# 105                pass                     carry      short_or_medium_pass
# 106                pass      short_or_medium_pass              third_assist
# 107                pass              third_assist      short_or_medium_pass
# 108                pass      short_or_medium_pass           progressive_run
# 109                pass           progressive_run      short_or_medium_pass
# 110                pass              lateral_pass              forward_pass
# 111                pass              forward_pass              lateral_pass
# 112                pass              lateral_pass          progressive_pass
# 113                pass          progressive_pass              lateral_pass
# 114                pass              lateral_pass                 long_pass
# 115                pass                 long_pass              lateral_pass
# 116                pass              lateral_pass       pass_to_final_third
# 117                pass       pass_to_final_third              lateral_pass
# 118                pass              lateral_pass                 hand_pass
# 119                pass                 hand_pass              lateral_pass
# 120                pass              lateral_pass                  recovery
# 121                pass                  recovery              lateral_pass
# 122                pass              lateral_pass            under_pressure
# 123                pass            under_pressure              lateral_pass
# 124                pass              lateral_pass                      loss
# 125                pass                      loss              lateral_pass
# 126                pass              lateral_pass                 head_pass
# 127                pass                 head_pass              lateral_pass
# 128                pass              lateral_pass  counterpressing_recovery
# 129                pass  counterpressing_recovery              lateral_pass
# 130                pass              lateral_pass               linkup_play
# 131                pass               linkup_play              lateral_pass
# 132                pass              lateral_pass           deep_completion
# 133                pass           deep_completion              lateral_pass
# 134                pass              lateral_pass              touch_in_box
# 135                pass              touch_in_box              lateral_pass
# 136                pass              lateral_pass                smart_pass
# 137                pass                smart_pass              lateral_pass
# 138                pass              lateral_pass                     cross
# 139                pass                     cross              lateral_pass
# 140                pass              lateral_pass      deep_completed_cross
# 141                pass      deep_completed_cross              lateral_pass
# 142                pass              lateral_pass      pass_to_penalty_area
# 143                pass      pass_to_penalty_area              lateral_pass
# 144                pass              lateral_pass             second_assist
# 145                pass             second_assist              lateral_pass
# 146                pass              lateral_pass                    assist
# 147                pass                    assist              lateral_pass
# 148                pass              lateral_pass                  key_pass
# 149                pass                  key_pass              lateral_pass
# 150                pass              lateral_pass               shot_assist
# 151                pass               shot_assist              lateral_pass
# 152                pass              lateral_pass             cross_blocked
# 153                pass             cross_blocked              lateral_pass
# 154                pass              lateral_pass              through_pass
# 155                pass              through_pass              lateral_pass
# 156                pass              lateral_pass                     carry
# 157                pass                     carry              lateral_pass
# 158                pass              lateral_pass              third_assist
# 159                pass              third_assist              lateral_pass
# 160                pass              lateral_pass           progressive_run
# 161                pass           progressive_run              lateral_pass
# 162                pass              forward_pass          progressive_pass
# 163                pass          progressive_pass              forward_pass
# 164                pass              forward_pass                 long_pass
# 165                pass                 long_pass              forward_pass
# 166                pass              forward_pass       pass_to_final_third
# 167                pass       pass_to_final_third              forward_pass
# 168                pass              forward_pass                 hand_pass
# 169                pass                 hand_pass              forward_pass
# 170                pass              forward_pass                  recovery
# 171                pass                  recovery              forward_pass
# 172                pass              forward_pass            under_pressure
# 173                pass            under_pressure              forward_pass
# 174                pass              forward_pass                      loss
# 175                pass                      loss              forward_pass
# 176                pass              forward_pass                 head_pass
# 177                pass                 head_pass              forward_pass
# 178                pass              forward_pass  counterpressing_recovery
# 179                pass  counterpressing_recovery              forward_pass
# 180                pass              forward_pass               linkup_play
# 181                pass               linkup_play              forward_pass
# 182                pass              forward_pass           deep_completion
# 183                pass           deep_completion              forward_pass
# 184                pass              forward_pass              touch_in_box
# 185                pass              touch_in_box              forward_pass
# 186                pass              forward_pass                smart_pass
# 187                pass                smart_pass              forward_pass
# 188                pass              forward_pass                     cross
# 189                pass                     cross              forward_pass
# 190                pass              forward_pass      deep_completed_cross
# 191                pass      deep_completed_cross              forward_pass
# 192                pass              forward_pass      pass_to_penalty_area
# 193                pass      pass_to_penalty_area              forward_pass
# 194                pass              forward_pass             second_assist
# 195                pass             second_assist              forward_pass
# 196                pass              forward_pass                    assist
# 197                pass                    assist              forward_pass
# 198                pass              forward_pass                  key_pass
# 199                pass                  key_pass              forward_pass
# 200                pass              forward_pass               shot_assist
# 201                pass               shot_assist              forward_pass
# 202                pass              forward_pass             cross_blocked
# 203                pass             cross_blocked              forward_pass
# 204                pass              forward_pass              through_pass
# 205                pass              through_pass              forward_pass
# 206                pass              forward_pass                     carry
# 207                pass                     carry              forward_pass
# 208                pass              forward_pass              third_assist
# 209                pass              third_assist              forward_pass
# 210                pass              forward_pass           progressive_run
# 211                pass           progressive_run              forward_pass
# 212                pass          progressive_pass                 long_pass
# 213                pass                 long_pass          progressive_pass
# 214                pass          progressive_pass       pass_to_final_third
# 215                pass       pass_to_final_third          progressive_pass
# 216                pass          progressive_pass                 hand_pass
# 217                pass                 hand_pass          progressive_pass
# 218                pass          progressive_pass                  recovery
# 219                pass                  recovery          progressive_pass
# 220                pass          progressive_pass            under_pressure
# 221                pass            under_pressure          progressive_pass
# 222                pass          progressive_pass                      loss
# 223                pass                      loss          progressive_pass
# 224                pass          progressive_pass                 head_pass
# 225                pass                 head_pass          progressive_pass
# 226                pass          progressive_pass  counterpressing_recovery
# 227                pass  counterpressing_recovery          progressive_pass
# 228                pass          progressive_pass               linkup_play
# 229                pass               linkup_play          progressive_pass
# 230                pass          progressive_pass           deep_completion
# 231                pass           deep_completion          progressive_pass
# 232                pass          progressive_pass              touch_in_box
# 233                pass              touch_in_box          progressive_pass
# 234                pass          progressive_pass                smart_pass
# 235                pass                smart_pass          progressive_pass
# 236                pass          progressive_pass                     cross
# 237                pass                     cross          progressive_pass
# 238                pass          progressive_pass      deep_completed_cross
# 239                pass      deep_completed_cross          progressive_pass
# 240                pass          progressive_pass      pass_to_penalty_area
# 241                pass      pass_to_penalty_area          progressive_pass
# 242                pass          progressive_pass             second_assist
# 243                pass             second_assist          progressive_pass
# 244                pass          progressive_pass                    assist
# 245                pass                    assist          progressive_pass
# 246                pass          progressive_pass                  key_pass
# 247                pass                  key_pass          progressive_pass
# 248                pass          progressive_pass               shot_assist
# 249                pass               shot_assist          progressive_pass
# 250                pass          progressive_pass             cross_blocked
# 251                pass             cross_blocked          progressive_pass
# 252                pass          progressive_pass              through_pass
# 253                pass              through_pass          progressive_pass
# 254                pass          progressive_pass                     carry
# 255                pass                     carry          progressive_pass
# 256                pass          progressive_pass              third_assist
# 257                pass              third_assist          progressive_pass
# 258                pass          progressive_pass           progressive_run
# 259                pass           progressive_run          progressive_pass
# 260                pass                 long_pass       pass_to_final_third
# 261                pass       pass_to_final_third                 long_pass
# 262                pass                 long_pass                 hand_pass
# 263                pass                 hand_pass                 long_pass
# 264                pass                 long_pass                  recovery
# 265                pass                  recovery                 long_pass
# 266                pass                 long_pass            under_pressure
# 267                pass            under_pressure                 long_pass
# 268                pass                 long_pass                      loss
# 269                pass                      loss                 long_pass
# 270                pass                 long_pass                 head_pass
# 271                pass                 head_pass                 long_pass
# 272                pass                 long_pass  counterpressing_recovery
# 273                pass  counterpressing_recovery                 long_pass
# 274                pass                 long_pass               linkup_play
# 275                pass               linkup_play                 long_pass
# 276                pass                 long_pass           deep_completion
# 277                pass           deep_completion                 long_pass
# 278                pass                 long_pass              touch_in_box
# 279                pass              touch_in_box                 long_pass
# 280                pass                 long_pass                smart_pass
# 281                pass                smart_pass                 long_pass
# 282                pass                 long_pass                     cross
# 283                pass                     cross                 long_pass
# 284                pass                 long_pass      deep_completed_cross
# 285                pass      deep_completed_cross                 long_pass
# 286                pass                 long_pass      pass_to_penalty_area
# 287                pass      pass_to_penalty_area                 long_pass
# 288                pass                 long_pass             second_assist
# 289                pass             second_assist                 long_pass
# 290                pass                 long_pass                    assist
# 291                pass                    assist                 long_pass
# 292                pass                 long_pass                  key_pass
# 293                pass                  key_pass                 long_pass
# 294                pass                 long_pass               shot_assist
# 295                pass               shot_assist                 long_pass
# 296                pass                 long_pass             cross_blocked
# 297                pass             cross_blocked                 long_pass
# 298                pass                 long_pass              through_pass
# 299                pass              through_pass                 long_pass
# 300                pass                 long_pass                     carry
# 301                pass                     carry                 long_pass
# 302                pass                 long_pass              third_assist
# 303                pass              third_assist                 long_pass
# 304                pass                 long_pass           progressive_run
# 305                pass           progressive_run                 long_pass
# 306                pass       pass_to_final_third                 hand_pass
# 307                pass                 hand_pass       pass_to_final_third
# 308                pass       pass_to_final_third                  recovery
# 309                pass                  recovery       pass_to_final_third
# 310                pass       pass_to_final_third            under_pressure
# 311                pass            under_pressure       pass_to_final_third
# 312                pass       pass_to_final_third                      loss
# 313                pass                      loss       pass_to_final_third
# 314                pass       pass_to_final_third                 head_pass
# 315                pass                 head_pass       pass_to_final_third
# 316                pass       pass_to_final_third  counterpressing_recovery
# 317                pass  counterpressing_recovery       pass_to_final_third
# 318                pass       pass_to_final_third               linkup_play
# 319                pass               linkup_play       pass_to_final_third
# 320                pass       pass_to_final_third           deep_completion
# 321                pass           deep_completion       pass_to_final_third
# 322                pass       pass_to_final_third              touch_in_box
# 323                pass              touch_in_box       pass_to_final_third
# 324                pass       pass_to_final_third                smart_pass
# 325                pass                smart_pass       pass_to_final_third
# 326                pass       pass_to_final_third                     cross
# 327                pass                     cross       pass_to_final_third
# 328                pass       pass_to_final_third      deep_completed_cross
# 329                pass      deep_completed_cross       pass_to_final_third
# 330                pass       pass_to_final_third      pass_to_penalty_area
# 331                pass      pass_to_penalty_area       pass_to_final_third
# 332                pass       pass_to_final_third             second_assist
# 333                pass             second_assist       pass_to_final_third
# 334                pass       pass_to_final_third                    assist
# 335                pass                    assist       pass_to_final_third
# 336                pass       pass_to_final_third                  key_pass
# 337                pass                  key_pass       pass_to_final_third
# 338                pass       pass_to_final_third               shot_assist
# 339                pass               shot_assist       pass_to_final_third
# 340                pass       pass_to_final_third             cross_blocked
# 341                pass             cross_blocked       pass_to_final_third
# 342                pass       pass_to_final_third              through_pass
# 343                pass              through_pass       pass_to_final_third
# 344                pass       pass_to_final_third                     carry
# 345                pass                     carry       pass_to_final_third
# 346                pass       pass_to_final_third              third_assist
# 347                pass              third_assist       pass_to_final_third
# 348                pass       pass_to_final_third           progressive_run
# 349                pass           progressive_run       pass_to_final_third
# 350                pass                 hand_pass                  recovery
# 351                pass                  recovery                 hand_pass
# 352                pass                 hand_pass            under_pressure
# 353                pass            under_pressure                 hand_pass
# 354                pass                 hand_pass                      loss
# 355                pass                      loss                 hand_pass
# 356                pass                 hand_pass                 head_pass
# 357                pass                 head_pass                 hand_pass
# 358                pass                 hand_pass  counterpressing_recovery
# 359                pass  counterpressing_recovery                 hand_pass
# 360                pass                 hand_pass               linkup_play
# 361                pass               linkup_play                 hand_pass
# 362                pass                 hand_pass           deep_completion
# 363                pass           deep_completion                 hand_pass
# 364                pass                 hand_pass              touch_in_box
# 365                pass              touch_in_box                 hand_pass
# 366                pass                 hand_pass                smart_pass
# 367                pass                smart_pass                 hand_pass
# 368                pass                 hand_pass                     cross
# 369                pass                     cross                 hand_pass
# 370                pass                 hand_pass      deep_completed_cross
# 371                pass      deep_completed_cross                 hand_pass
# 372                pass                 hand_pass      pass_to_penalty_area
# 373                pass      pass_to_penalty_area                 hand_pass
# 374                pass                 hand_pass             second_assist
# 375                pass             second_assist                 hand_pass
# 376                pass                 hand_pass                    assist
# 377                pass                    assist                 hand_pass
# 378                pass                 hand_pass                  key_pass
# 379                pass                  key_pass                 hand_pass
# 380                pass                 hand_pass               shot_assist
# 381                pass               shot_assist                 hand_pass
# 382                pass                 hand_pass             cross_blocked
# 383                pass             cross_blocked                 hand_pass
# 384                pass                 hand_pass              through_pass
# 385                pass              through_pass                 hand_pass
# 386                pass                 hand_pass                     carry
# 387                pass                     carry                 hand_pass
# 388                pass                 hand_pass              third_assist
# 389                pass              third_assist                 hand_pass
# 390                pass                 hand_pass           progressive_run
# 391                pass           progressive_run                 hand_pass
# 392                pass                  recovery            under_pressure
# 393                pass            under_pressure                  recovery
# 394                pass                  recovery                      loss
# 395                pass                      loss                  recovery
# 396                pass                  recovery                 head_pass
# 397                pass                 head_pass                  recovery
# 398                pass                  recovery  counterpressing_recovery
# 399                pass  counterpressing_recovery                  recovery
# 400                pass                  recovery               linkup_play
# 401                pass               linkup_play                  recovery
# 402                pass                  recovery           deep_completion
# 403                pass           deep_completion                  recovery
# 404                pass                  recovery              touch_in_box
# 405                pass              touch_in_box                  recovery
# 406                pass                  recovery                smart_pass
# 407                pass                smart_pass                  recovery
# 408                pass                  recovery                     cross
# 409                pass                     cross                  recovery
# 410                pass                  recovery      deep_completed_cross
# 411                pass      deep_completed_cross                  recovery
# 412                pass                  recovery      pass_to_penalty_area
# 413                pass      pass_to_penalty_area                  recovery
# 414                pass                  recovery             second_assist
# 415                pass             second_assist                  recovery
# 416                pass                  recovery                    assist
# 417                pass                    assist                  recovery
# 418                pass                  recovery                  key_pass
# 419                pass                  key_pass                  recovery
# 420                pass                  recovery               shot_assist
# 421                pass               shot_assist                  recovery
# 422                pass                  recovery             cross_blocked
# 423                pass             cross_blocked                  recovery
# 424                pass                  recovery              through_pass
# 425                pass              through_pass                  recovery
# 426                pass                  recovery                     carry
# 427                pass                     carry                  recovery
# 428                pass                  recovery              third_assist
# 429                pass              third_assist                  recovery
# 430                pass                  recovery           progressive_run
# 431                pass           progressive_run                  recovery
# 432                pass            under_pressure                      loss
# 433                pass                      loss            under_pressure
# 434                pass            under_pressure                 head_pass
# 435                pass                 head_pass            under_pressure
# 436                pass            under_pressure  counterpressing_recovery
# 437                pass  counterpressing_recovery            under_pressure
# 438                pass            under_pressure               linkup_play
# 439                pass               linkup_play            under_pressure
# 440                pass            under_pressure           deep_completion
# 441                pass           deep_completion            under_pressure
# 442                pass            under_pressure              touch_in_box
# 443                pass              touch_in_box            under_pressure
# 444                pass            under_pressure                smart_pass
# 445                pass                smart_pass            under_pressure
# 446                pass            under_pressure                     cross
# 447                pass                     cross            under_pressure
# 448                pass            under_pressure      deep_completed_cross
# 449                pass      deep_completed_cross            under_pressure
# 450                pass            under_pressure      pass_to_penalty_area
# 451                pass      pass_to_penalty_area            under_pressure
# 452                pass            under_pressure             second_assist
# 453                pass             second_assist            under_pressure
# 454                pass            under_pressure                    assist
# 455                pass                    assist            under_pressure
# 456                pass            under_pressure                  key_pass
# 457                pass                  key_pass            under_pressure
# 458                pass            under_pressure               shot_assist
# 459                pass               shot_assist            under_pressure
# 460                pass            under_pressure             cross_blocked
# 461                pass             cross_blocked            under_pressure
# 462                pass            under_pressure              through_pass
# 463                pass              through_pass            under_pressure
# 464                pass            under_pressure                     carry
# 465                pass                     carry            under_pressure
# 466                pass            under_pressure              third_assist
# 467                pass              third_assist            under_pressure
# 468                pass            under_pressure           progressive_run
# 469                pass           progressive_run            under_pressure
# 470                pass                      loss                 head_pass
# 471                pass                 head_pass                      loss
# 472                pass                      loss  counterpressing_recovery
# 473                pass  counterpressing_recovery                      loss
# 474                pass                      loss               linkup_play
# 475                pass               linkup_play                      loss
# 476                pass                      loss           deep_completion
# 477                pass           deep_completion                      loss
# 478                pass                      loss              touch_in_box
# 479                pass              touch_in_box                      loss
# 480                pass                      loss                smart_pass
# 481                pass                smart_pass                      loss
# 482                pass                      loss                     cross
# 483                pass                     cross                      loss
# 484                pass                      loss      deep_completed_cross
# 485                pass      deep_completed_cross                      loss
# 486                pass                      loss      pass_to_penalty_area
# 487                pass      pass_to_penalty_area                      loss
# 488                pass                      loss             second_assist
# 489                pass             second_assist                      loss
# 490                pass                      loss                    assist
# 491                pass                    assist                      loss
# 492                pass                      loss                  key_pass
# 493                pass                  key_pass                      loss
# 494                pass                      loss               shot_assist
# 495                pass               shot_assist                      loss
# 496                pass                      loss             cross_blocked
# 497                pass             cross_blocked                      loss
# 498                pass                      loss              through_pass
# 499                pass              through_pass                      loss
# 500                pass                      loss                     carry
# 501                pass                     carry                      loss
# 502                pass                      loss              third_assist
# 503                pass              third_assist                      loss
# 504                pass                      loss           progressive_run
# 505                pass           progressive_run                      loss
# 506                pass                 head_pass  counterpressing_recovery
# 507                pass  counterpressing_recovery                 head_pass
# 508                pass                 head_pass               linkup_play
# 509                pass               linkup_play                 head_pass
# 510                pass                 head_pass           deep_completion
# 511                pass           deep_completion                 head_pass
# 512                pass                 head_pass              touch_in_box
# 513                pass              touch_in_box                 head_pass
# 514                pass                 head_pass                smart_pass
# 515                pass                smart_pass                 head_pass
# 516                pass                 head_pass                     cross
# 517                pass                     cross                 head_pass
# 518                pass                 head_pass      deep_completed_cross
# 519                pass      deep_completed_cross                 head_pass
# 520                pass                 head_pass      pass_to_penalty_area
# 521                pass      pass_to_penalty_area                 head_pass
# 522                pass                 head_pass             second_assist
# 523                pass             second_assist                 head_pass
# 524                pass                 head_pass                    assist
# 525                pass                    assist                 head_pass
# 526                pass                 head_pass                  key_pass
# 527                pass                  key_pass                 head_pass
# 528                pass                 head_pass               shot_assist
# 529                pass               shot_assist                 head_pass
# 530                pass                 head_pass             cross_blocked
# 531                pass             cross_blocked                 head_pass
# 532                pass                 head_pass              through_pass
# 533                pass              through_pass                 head_pass
# 534                pass                 head_pass                     carry
# 535                pass                     carry                 head_pass
# 536                pass                 head_pass              third_assist
# 537                pass              third_assist                 head_pass
# 538                pass                 head_pass           progressive_run
# 539                pass           progressive_run                 head_pass
# 540                pass  counterpressing_recovery               linkup_play
# 541                pass               linkup_play  counterpressing_recovery
# 542                pass  counterpressing_recovery           deep_completion
# 543                pass           deep_completion  counterpressing_recovery
# 544                pass  counterpressing_recovery              touch_in_box
# 545                pass              touch_in_box  counterpressing_recovery
# 546                pass  counterpressing_recovery                smart_pass
# 547                pass                smart_pass  counterpressing_recovery
# 548                pass  counterpressing_recovery                     cross
# 549                pass                     cross  counterpressing_recovery
# 550                pass  counterpressing_recovery      deep_completed_cross
# 551                pass      deep_completed_cross  counterpressing_recovery
# 552                pass  counterpressing_recovery      pass_to_penalty_area
# 553                pass      pass_to_penalty_area  counterpressing_recovery
# 554                pass  counterpressing_recovery             second_assist
# 555                pass             second_assist  counterpressing_recovery
# 556                pass  counterpressing_recovery                    assist
# 557                pass                    assist  counterpressing_recovery
# 558                pass  counterpressing_recovery                  key_pass
# 559                pass                  key_pass  counterpressing_recovery
# 560                pass  counterpressing_recovery               shot_assist
# 561                pass               shot_assist  counterpressing_recovery
# 562                pass  counterpressing_recovery             cross_blocked
# 563                pass             cross_blocked  counterpressing_recovery
# 564                pass  counterpressing_recovery              through_pass
# 565                pass              through_pass  counterpressing_recovery
# 566                pass  counterpressing_recovery                     carry
# 567                pass                     carry  counterpressing_recovery
# 568                pass  counterpressing_recovery              third_assist
# 569                pass              third_assist  counterpressing_recovery
# 570                pass  counterpressing_recovery           progressive_run
# 571                pass           progressive_run  counterpressing_recovery
# 572                pass               linkup_play           deep_completion
# 573                pass           deep_completion               linkup_play
# 574                pass               linkup_play              touch_in_box
# 575                pass              touch_in_box               linkup_play
# 576                pass               linkup_play                smart_pass
# 577                pass                smart_pass               linkup_play
# 578                pass               linkup_play                     cross
# 579                pass                     cross               linkup_play
# 580                pass               linkup_play      deep_completed_cross
# 581                pass      deep_completed_cross               linkup_play
# 582                pass               linkup_play      pass_to_penalty_area
# 583                pass      pass_to_penalty_area               linkup_play
# 584                pass               linkup_play             second_assist
# 585                pass             second_assist               linkup_play
# 586                pass               linkup_play                    assist
# 587                pass                    assist               linkup_play
# 588                pass               linkup_play                  key_pass
# 589                pass                  key_pass               linkup_play
# 590                pass               linkup_play               shot_assist
# 591                pass               shot_assist               linkup_play
# 592                pass               linkup_play             cross_blocked
# 593                pass             cross_blocked               linkup_play
# 594                pass               linkup_play              through_pass
# 595                pass              through_pass               linkup_play
# 596                pass               linkup_play                     carry
# 597                pass                     carry               linkup_play
# 598                pass               linkup_play              third_assist
# 599                pass              third_assist               linkup_play
# 600                pass               linkup_play           progressive_run
# 601                pass           progressive_run               linkup_play
# 602                pass           deep_completion              touch_in_box
# 603                pass              touch_in_box           deep_completion
# 604                pass           deep_completion                smart_pass
# 605                pass                smart_pass           deep_completion
# ...
# 1878         0.0
# 1879         0.0
# 1880         0.0
# 1881         0.0
# 1882         0.0
# 1883         0.0
# 1884         0.0
# 1885         0.0
# 1886         0.0
# 1887         0.0
# 1888         0.0
# 1889         0.0
# 1890         0.0
# 1891         0.0
# 1892         0.0
# 1893         0.0
# 1894         0.0
# 1895         0.0
# 1896         0.0
# 1897         0.0
# 1898         0.0
# 1899         0.0
# 1900         0.0
# 1901         0.0
# 1902         0.0
# 1903         0.0
# 1904         0.0
# 1905         0.0
# 1906         0.0
# 1907         0.0
# 1908         0.0
# 1909         0.0
# 1910         0.0
# 1911         0.0
# 1912         0.0
# 1913         0.0
# 1914         0.0
# 1915         0.0
# 1916         0.0
# 1917         0.0
# 1918         0.0
# 1919         0.0
# 1920         0.0
# 1921         0.0
# 1922         0.0
# 1923         0.0
# 1924         0.0
# 1925         0.0
# 1926         0.0
# 1927         0.0
# 1928         0.0
# 1929         0.0
# 1930         0.0
# 1931         0.0
# 1932         0.0
# 1933         0.0
# 1934         0.0
# 1935         0.0
# 1936         0.0
# 1937         0.0
# 1938         0.0
# 1939         0.0
# 1940         0.0
# 1941         0.0
# 1942         0.0
# 1943         0.0
# 1944         0.0
# 1945         0.0
# 1946         0.0
# 1947         0.0
# 1948         0.0
# 1949         0.0
# 1950         0.0
# 1951         0.0
# 1952         0.0
# 1953         0.0
# 1954         0.0
# 1955         0.0
# 1956         0.0
# 1957         0.0
# 1958         0.0
# 1959         0.0
# 1960         0.0
# 1961         0.0
# 1962         0.0
# 1963         0.0
# 1964         0.0
# 1965         0.0
# 1966         0.0
# 1967         0.0
# 1968         0.0
# 1969         0.0
# 1970         0.0
# 1971         0.0
# 1972         0.0
# 1973         0.0
# 1974         0.0
# 1975         0.0
# 1976         0.0
# 1977         0.0
# 1978         0.0
# 1979         0.0
# 1980         0.0
# 1981         0.0
# 1982         0.0
# 1983         0.0
# 1984         0.0
# 1985         0.0
# 1986         0.0
# 1987         0.0
# 1988         0.0
# 1989         0.0
# 1990         0.0
# 1991         0.0
# 1992         0.0
# 1993         0.0
# 1994         0.0
# 1995         0.0
# 1996         0.0
# 1997         0.0
# 1998         0.0
# 1999         0.0
# 2000         0.0
# 2001         0.0
# 2002         0.0
# 2003         0.0
# 2004         0.0
# 2005         0.0
# 2006         0.0
# 2007         0.0
# 2008         0.0
# 2009         0.0
# 2010         0.0
# 2011         0.0
# 2012         0.0
# 2013         0.0
# 2014         0.0
# 2015         0.0
# 2016         0.0
# 2017         0.0
# 2018         0.0
# 2019         0.0
# 2020         0.0
# 2021         0.0
# 2022         0.0
# 2023         0.0
# 2024         0.0
# 2025         0.0
# 2026         0.0
# 2027         0.0
# 2028         0.0
# 2029         0.0
# 2030         0.0
# 2031         0.0
# 2032         0.0
# 2033         0.0
# 2034         0.0
# 2035         0.0
# 2036         0.0
# 2037         0.0
# 2038         0.0
# 2039         0.0
# 2040         0.0
# 2041         0.0
# 2042         0.0
# 2043         0.0
# 2044         0.0
# 2045         0.0
# 2046         0.0
# 2047         0.0
# 2048         0.0
# 2049         0.0
# 2050         0.0
# 2051         0.0
# 2052         0.0
# 2053         0.0
# 2054         0.0
# 2055         0.0
# 2056         0.0
# 2057         0.0
# 2058         0.0
# 2059         0.0
# 2060         0.0
# 2061         0.0
# 2062         0.0
# 2063         0.0
# 2064         0.0
# 2065         0.0
# 2066         0.0
# 2067         0.0
# 2068         0.0
# 2069         0.0
# 2070         0.0
# 2071         0.0
# 2072         0.0
# 2073         0.0
# 2074         0.0
# 2075         0.0
# 2076         0.0
# 2077         0.0
# 2078         0.0
# 2079         0.0
# 2080         0.0
# 2081         0.0
# 2082         0.0
# 2083         0.0
# 2084         0.0
# 2085         0.0
# 2086         0.0
# 2087         0.0
# 2088         0.0
# 2089         0.0
# 2090         0.0
# 2091         0.0
# 2092         0.0
# 2093         0.0
# 2094         0.0
# 2095         0.0
# 2096         0.0
# 2097         0.0
# 2098         0.0
# 2099         0.0
# 2100         0.0
# 2101         0.0
# 2102         0.0
# 2103         0.0
# 2104         0.0
# 2105         0.0
# 2106         0.0
# 2107         0.0
# 2108         0.0
# 2109         0.0
# 2110         0.0
# 2111         0.0
# 2112         0.0
# 2113         0.0
# 2114         0.0
# 2115         0.0
# 2116         0.0
# 2117         0.0
# 2118         0.0
# 2119         0.0
# 2120         0.0
# 2121         0.0
# 2122         0.0
# 2123         0.0
# 2124         0.0
# 2125         0.0
# 2126         0.0
# 2127         0.0
# 2128         0.0
# 2129         0.0
# 2130         0.0
# 2131         0.0
# 2132         0.0
# 2133         0.0
# 2134         0.0
# 2135         0.0
# 2136         0.0
# 2137         0.0
# 2138         0.0
# 2139         0.0
# 2140         0.0
# 2141         0.0
# 2142         0.0
# 2143         0.0
# 2144         0.0
# 2145         0.0
# 2146         0.0
# 2147         0.0
# 2148         0.0
# 2149         0.0
# 2150         0.0
# 2151         0.0
# 2152         0.0
# 2153         0.0
# 2154         0.0
# 2155         0.0
# 2156         0.0
# 2157         0.0
# 2158         0.0
# 2159         0.0
# 2160         0.0
# 2161         0.0
# 2162         0.0
# 2163         0.0
# 2164         0.0
# 2165         0.0
# 2166         0.0
# 2167         0.0
# 2168         0.0
# 2169         0.0
# 2170         0.0
# 2171         0.0
# 2172         0.0
# 2173         0.0
# 2174         0.0
# 2175         0.0
# 2176         0.0
# 2177         0.0
# 2178         0.0
# 2179         0.0
# 2180         0.0
# 2181         0.0
# 2182         0.0
# 2183         0.0
# 2184         0.0
# 2185         0.0
# 2186         0.0
# 2187         0.0
# 2188         0.0
# 2189         0.0
# 2190         0.0
# 2191         0.0
# 2192         0.0
# 2193         0.0
# 2194         0.0
# 2195         0.0
# 2196         0.0
# 2197         0.0
# 2198         0.0
# 2199         0.0
# 2200         0.0
# 2201         0.0
# 2202         0.0
# 2203         0.0
# 2204         0.0
# 2205         0.0
# 2206         0.0
# 2207         0.0
# 2208         0.0
# 2209         0.0
# 2210         0.0
# 2211         0.0
# 2212         0.0
# 2213         0.0
# 2214         0.0
# 2215         0.0
# 2216         0.0
# 2217         0.0
# 2218         0.0
# 2219         0.0
# 2220         0.0
# 2221         0.0
# 2222         0.0
# 2223         0.0
# 2224         0.0
# 2225         0.0
# 2226         0.0
# 2227         0.0
# 2228         0.0
# 2229         0.0
# 2230         0.0
# 2231         0.0
# 2232         0.0
# 2233         0.0
# 2234         0.0
# 2235         0.0
# 2236         0.0
# 2237         0.0
# 2238         0.0
# 2239         0.0
# 2240         0.0
# 2241         0.0
# 2242         0.0
# 2243         0.0
# 2244         0.0
# 2245         0.0
# 2246         0.0
# 2247         0.0
# 2248         0.0
# 2249         0.0
# 2250         0.0
# 2251         0.0
# 2252         0.0
# 2253         0.0
# 2254         0.0
# 2255         0.0
# 2256         0.0
# 2257         0.0
# 2258         0.0
# 2259         0.0
# 2260         0.0
# 2261         0.0
# 2262         0.0
# 2263         0.0
# 2264         0.0
# 2265         0.0
# 2266         0.0
# 2267         0.0
# 2268         0.0
# 2269         0.0
# 2270         0.0
# 2271         0.0
# 2272         0.0
# 2273         0.0
# 2274         0.0
# 2275         0.0
# 2276         0.0
# 2277         0.0
# 2278         0.0
# 2279         0.0
# 2280         0.0
# 2281         0.0
# 2282         0.0
# 2283         0.0
# 2284         0.0
# 2285         0.0
# 2286         0.0
# 2287         0.0
# 2288         0.0
# 2289         0.0
# 2290         0.0
# 2291         0.0
# 2292         0.0
# 2293         0.0
# 2294         0.0
# 2295         0.0
# 2296         0.0
# 2297         0.0
# 2298         0.0
# 2299         0.0
# 2300         0.0
# 2301         0.0
# 2302         0.0
# 2303         0.0
# 2304         0.0
# 2305         0.0
# 2306         0.0
# 2307         0.0
# 2308         0.0
# 2309         0.0
# 2310         0.0
# 2311         0.0
# 2312         0.0
# 2313         0.0
# 2314         0.0
# 2315         0.0
# 2316         0.0
# 2317         0.0
# 2318         0.0
# 2319         0.0
# 2320         0.0
# 2321         0.0
# 2322         0.0
# 2323         0.0
# 2324         0.0
# 2325         0.0
# 2326         0.0
# 2327         0.0
# 2328         0.0
# 2329         0.0
# 2330         0.0
# 2331         0.0
# 2332         0.0
# 2333         0.0
# 2334         0.0
# 2335         0.0
# 2336         0.0
# 2337         0.0
# 2338         0.0
# 2339         0.0
# 2340         0.0
# 2341         0.0
# 2342         0.0
# 2343         0.0
# 2344         0.0
# 2345         0.0
# 2346         0.0
# 2347         0.0
# 2348         0.0
# 2349         0.0
# 2350         0.0
# 2351         0.0
# 2352         0.0
# 2353         0.0
# 2354         0.0
# 2355         0.0
# 2356         0.0
# 2357         0.0
# 2358         0.0
# 2359         0.0
# 2360         0.0
# 2361         0.0
# 2362         0.0
# 2363         0.0
# 2364         0.0
# 2365         0.0
# 2366         0.0
# 2367         0.0
# 2368         0.0
# 2369         0.0
# 2370         0.0
# 2371         0.0
# 2372         0.0
# 2373         0.0
# 2374         0.0
# 2375         0.0
# 2376         0.0
# 2377         0.0
# 2378         0.0
# 2379         0.0
# 2380         0.0
# 2381         0.0
# 2382         0.0
# 2383         0.0
# 2384         0.0
# 2385         0.0
# 2386         0.0
# 2387         0.0
# 2388         0.0
# 2389         0.0
# 2390         0.0
# 2391         0.0
# 2392         0.0
# 2393         0.0
# 2394         0.0
# 2395         0.0
# 2396         0.0
# 2397         0.0
# 2398         0.0
# 2399         0.0
# 2400         0.0
# 2401         0.0
# 2402         0.0
# 2403         0.0
# 2404         0.0
# 2405         0.0
# 2406         0.0
# 2407         0.0
# 2408         0.0
# 2409         0.0
# 2410         0.0
# 2411         0.0
# 2412         0.0
# 2413         0.0
# 2414         0.0
# 2415         0.0
# 2416         0.0
# 2417         0.0
# 2418         0.0
# 2419         0.0
# 2420         0.0
# 2421         0.0
# 2422         0.0
# 2423         0.0
# 2424         0.0
# 2425         0.0
# 2426         0.0
# 2427         0.0
# 2428         0.0
# 2429         0.0
# 2430         0.0
# 2431         0.0
# 2432         0.0
# 2433         0.0
# 2434         0.0
# 2435         0.0
# 2436         0.0
# 2437         0.0
# 2438         0.0
# 2439         0.0
# 2440         0.0
# 2441         0.0
# 2442         0.0
# 2443         0.0
# 2444         0.0
# 2445         0.0
# 2446         0.0
# 2447         0.0
# 2448         0.0
# 2449         0.0
# 2450         0.0
# 2451         0.0
# 2452         0.0
# 2453         0.0
# 2454         0.0
# 2455         0.0
# 2456         0.0
# 2457         0.0
# 2458         0.0
# 2459         0.0
# 2460         0.0
# 2461         0.0
# 2462         0.0
# 2463         0.0
# 2464         0.0
# 2465         0.0
# 2466         0.0
# 2467         0.0
# 2468         0.0
# 2469         0.0
# 2470         0.0
# 2471         0.0
# 2472         0.0
# 2473         0.0
# 2474         0.0
# 2475         0.0
# 2476         0.0
# 2477         0.0
# 2478         0.0
# 2479         0.0
# 2480         0.0
# 2481         0.0
# 2482         0.0
# 2483         0.0
# 2484         0.0
# 2485         0.0
# 2486         0.0
# 2487         0.0
# 2488         0.0
# 2489         0.0
# 2490         0.0
# 2491         0.0
# 2492         0.0
# 2493         0.0
# 2494         0.0
# 2495         0.0
# 2496         0.0
# 2497         0.0
# 2498         0.0
# 2499         0.0
# 2500         0.0
# 2501         0.0
# 2502         0.0
# 2503         0.0
# 2504         0.0
# 2505         0.0
# 2506         0.0
# 2507         0.0
# 2508         0.0
# 2509         0.0
# 2510         0.0
# 2511         0.0
# 2512         0.0
# 2513         0.0
# 2514         0.0
# 2515         0.0
# 2516         0.0
# 2517         0.0
# 2518         0.0
# 2519         0.0
# 2520         0.0
# 2521         0.0
# 2522         0.0
# 2523         0.0
# 2524         0.0
# 2525         0.0
# 2526         0.0
# 2527         0.0
# 2528         0.0
# 2529         0.0
# 2530         0.0
# 2531         0.0
# 2532         0.0
# 2533         0.0
# 2534         0.0
# 2535         0.0
# 2536         0.0
# 2537         0.0
# 2538         0.0
# 2539         0.0
# 2540         0.0
# 2541         0.0
# 2542         0.0
# 2543         0.0
# 2544         0.0
# 2545         0.0
# 2546         0.0
# 2547         0.0
# 2548         0.0
# 2549         0.0
# 2550         0.0
# 2551         0.0
# 2552         0.0
# 2553         0.0
# 2554         0.0
# 2555         0.0
# 2556         0.0
# 2557         0.0
# 2558         0.0
# 2559         0.0
# 2560         0.0
# 2561         0.0
# 2562         0.0
# 2563         0.0
# 2564         0.0
# 2565         0.0
# 2566         0.0
# 2567         0.0
# 2568         0.0
# 2569         0.0
# 2570         0.0
# 2571         0.0
# 2572         0.0
# 2573         0.0
# 2574         0.0
# 2575         0.0
# 2576         0.0
# 2577         0.0
# 2578         0.0
# 2579         0.0
# 2580         0.0
# 2581         0.0
# 2582         0.0
# 2583         0.0
# 2584         0.0
# 2585         0.0
# 2586         0.0
# 2587         0.0
# 2588         0.0
# 2589         0.0
# 2590         0.0
# 2591         0.0
# 2592         0.0
# 2593         0.0
# 2594         0.0
# 2595         0.0
# 2596         0.0
# 2597         0.0
# 2598         0.0
# 2599         0.0
# 2600         0.0
# 2601         0.0
# 2602         0.0
# 2603         0.0
# 2604         0.0
# 2605         0.0
# 2606         0.0
# 2607         0.0
# 2608         0.0
# 2609         0.0
# 2610         0.0
# 2611         0.0
# 2612         0.0
# 2613         0.0
# 2614         0.0
# 2615         0.0
# 2616         0.0
# 2617         0.0
# 2618         0.0
# 2619         0.0
# 2620         0.0
# 2621         0.0
# 2622         0.0
# 2623         0.0
# 2624         0.0
# 2625         0.0
# 2626         0.0
# 2627         0.0
# 2628         0.0
# 2629         0.0
# 2630         0.0
# 2631         0.0
# 2632         0.0
# 2633         0.0
# 2634         0.0
# 2635         0.0
# 2636         0.0
# 2637         0.0
# 2638         0.0
# 2639         0.0
# 2640         0.0
# 2641         0.0
# 2642         0.0
# 2643         0.0
# 2644         0.0
# 2645         0.0
# 2646         0.0
# 2647         0.0
# 2648         0.0
# 2649         0.0
# 2650         0.0
# 2651         0.0
# 2652         0.0
# 2653         0.0
# 2654         0.0
# 2655         0.0
# 2656         0.0
# 2657         0.0
# 2658         0.0
# 2659         0.0
# 2660         0.0
# 2661         0.0
# 2662         0.0
# 2663         0.0
# 2664         0.0
# 2665         0.0
# 2666         0.0
# 2667         0.0
# 2668         0.0
# 2669         0.0
# 2670         0.0
# 2671         0.0
# 2672         0.0
# 2673         0.0
# 2674         0.0
# 2675         0.0
# 2676         0.0
# 2677         0.0
# 2678         0.0
# 2679         0.0
# 2680         0.0
# 2681         0.0
# 2682         0.0
# 2683         0.0
# 2684         0.0
# 2685         0.0
# 2686         0.0
# 2687         0.0
# 2688         0.0
# 2689         0.0
# 2690         0.0
# 2691         0.0
# 2692         0.0
# 2693         0.0
# 2694         0.0
# 2695         0.0
# 2696         0.0
# 2697         0.0
# 2698         0.0
# 2699         0.0
# 2700         0.0
# 2701         0.0
# 2702         0.0
# 2703         0.0
# 2704         0.0
# 2705         0.0
# 2706         0.0
# 2707         0.0
# 2708         0.0
# 2709         0.0
# 2710         0.0
# 2711         0.0
# 2712         0.0
# 2713         0.0
# 2714         0.0
# 2715         0.0
# 2716         0.0
# 2717         0.0
# 2718         0.0
# 2719         0.0

# %%
# Initialize a defaultdict to store counts
primary_secondary_count = defaultdict(lambda: defaultdict(int))

# Iterate through each row in the DataFrame
for index, row in df.iterrows():
    primary_type = row['primary_type']
    secondary_types = row['secondary_types']
    
    # Check if secondary_types is not NaN
    if pd.notna(secondary_types):
        secondary_types = secondary_types.split(',')  # Split by comma if necessary
        
        # Count occurrences of each secondary type for the current primary type
        for secondary_type in secondary_types:
            primary_secondary_count[primary_type][secondary_type.strip()] += 1  # Strip to remove any extra whitespace

# Convert defaultdict to regular dictionary for easier manipulation (if needed)
primary_secondary_count = dict(primary_secondary_count)

# Print the result
for primary_type, secondary_counts in primary_secondary_count.items():
    for secondary_type, count in secondary_counts.items():
        print(f"Primary Type: {primary_type}, Secondary Type: {secondary_type}, Occurrences: {count}")
# Out:
# Primary Type: pass, Secondary Type: back_pass, Occurrences: 36345
# Primary Type: pass, Secondary Type: short_or_medium_pass, Occurrences: 213353
# Primary Type: pass, Secondary Type: lateral_pass, Occurrences: 94132
# Primary Type: pass, Secondary Type: forward_pass, Occurrences: 78835
# Primary Type: pass, Secondary Type: progressive_pass, Occurrences: 37744
# Primary Type: pass, Secondary Type: long_pass, Occurrences: 24686
# Primary Type: pass, Secondary Type: pass_to_final_third, Occurrences: 27661
# Primary Type: pass, Secondary Type: hand_pass, Occurrences: 1672
# Primary Type: pass, Secondary Type: recovery, Occurrences: 16784
# Primary Type: pass, Secondary Type: under_pressure, Occurrences: 11959
# Primary Type: pass, Secondary Type: loss, Occurrences: 28135
# Primary Type: pass, Secondary Type: head_pass, Occurrences: 9893
# Primary Type: pass, Secondary Type: counterpressing_recovery, Occurrences: 8051
# Primary Type: pass, Secondary Type: linkup_play, Occurrences: 6370
# Primary Type: pass, Secondary Type: deep_completion, Occurrences: 4029
# Primary Type: pass, Secondary Type: touch_in_box, Occurrences: 4440
# Primary Type: pass, Secondary Type: smart_pass, Occurrences: 1576
# Primary Type: pass, Secondary Type: cross, Occurrences: 8627
# Primary Type: pass, Secondary Type: deep_completed_cross, Occurrences: 2954
# Primary Type: pass, Secondary Type: pass_to_penalty_area, Occurrences: 11034
# Primary Type: pass, Secondary Type: second_assist, Occurrences: 179
# Primary Type: pass, Secondary Type: assist, Occurrences: 361
# Primary Type: pass, Secondary Type: key_pass, Occurrences: 1915
# Primary Type: pass, Secondary Type: shot_assist, Occurrences: 3474
# Primary Type: pass, Secondary Type: cross_blocked, Occurrences: 1462
# Primary Type: pass, Secondary Type: through_pass, Occurrences: 3139
# Primary Type: pass, Secondary Type: carry, Occurrences: 931
# Primary Type: pass, Secondary Type: third_assist, Occurrences: 129
# Primary Type: pass, Secondary Type: progressive_run, Occurrences: 94
# Primary Type: duel, Secondary Type: loose_ball_duel, Occurrences: 19582
# Primary Type: duel, Secondary Type: carry, Occurrences: 10169
# Primary Type: duel, Secondary Type: foul_suffered, Occurrences: 6545
# Primary Type: duel, Secondary Type: ground_duel, Occurrences: 78226
# Primary Type: duel, Secondary Type: linkup_play, Occurrences: 2294
# Primary Type: duel, Secondary Type: offensive_duel, Occurrences: 39113
# Primary Type: duel, Secondary Type: defensive_duel, Occurrences: 39113
# Primary Type: duel, Secondary Type: dribble, Occurrences: 14614
# Primary Type: duel, Secondary Type: loss, Occurrences: 17106
# Primary Type: duel, Secondary Type: recovery, Occurrences: 17894
# Primary Type: duel, Secondary Type: aerial_duel, Occurrences: 20566
# Primary Type: duel, Secondary Type: counterpressing_recovery, Occurrences: 8530
# Primary Type: duel, Secondary Type: interception, Occurrences: 880
# Primary Type: duel, Secondary Type: sliding_tackle, Occurrences: 1677
# Primary Type: duel, Secondary Type: progressive_run, Occurrences: 1318
# Primary Type: duel, Secondary Type: dribbled_past_attempt, Occurrences: 5996
# Primary Type: duel, Secondary Type: second_assist, Occurrences: 29
# Primary Type: duel, Secondary Type: assist, Occurrences: 17
# Primary Type: duel, Secondary Type: opportunity, Occurrences: 10
# Primary Type: duel, Secondary Type: third_assist, Occurrences: 6
# Primary Type: duel, Secondary Type: shot_block, Occurrences: 2
# Primary Type: touch, Secondary Type: carry, Occurrences: 26262
# Primary Type: touch, Secondary Type: touch_in_box, Occurrences: 1549
# Primary Type: touch, Secondary Type: progressive_run, Occurrences: 5908
# Primary Type: touch, Secondary Type: loss, Occurrences: 3843
# Primary Type: touch, Secondary Type: opportunity, Occurrences: 238
# Primary Type: touch, Secondary Type: under_pressure, Occurrences: 483
# Primary Type: touch, Secondary Type: second_assist, Occurrences: 5
# Primary Type: touch, Secondary Type: third_assist, Occurrences: 4
# Primary Type: touch, Secondary Type: assist, Occurrences: 1
# Primary Type: shot, Secondary Type: opportunity, Occurrences: 4841
# Primary Type: shot, Secondary Type: goal, Occurrences: 649
# Primary Type: shot, Secondary Type: touch_in_box, Occurrences: 3941
# Primary Type: shot, Secondary Type: shot_after_throw_in, Occurrences: 480
# Primary Type: shot, Secondary Type: shot_after_corner, Occurrences: 997
# Primary Type: shot, Secondary Type: head_shot, Occurrences: 1126
# Primary Type: shot, Secondary Type: shot_after_free_kick, Occurrences: 316
# Primary Type: shot, Secondary Type: interception, Occurrences: 38
# Primary Type: shot, Secondary Type: shot_block, Occurrences: 7
# Primary Type: shot, Secondary Type: assist, Occurrences: 2
# Primary Type: clearance, Secondary Type: head_pass, Occurrences: 588
# Primary Type: clearance, Secondary Type: recovery, Occurrences: 146
# Primary Type: clearance, Secondary Type: under_pressure, Occurrences: 341
# Primary Type: clearance, Secondary Type: loss, Occurrences: 973
# Primary Type: clearance, Secondary Type: carry, Occurrences: 19
# Primary Type: clearance, Secondary Type: counterpressing_recovery, Occurrences: 54
# Primary Type: clearance, Secondary Type: linkup_play, Occurrences: 1
# Primary Type: game_interruption, Secondary Type: ball_out, Occurrences: 19045
# Primary Type: game_interruption, Secondary Type: whistle, Occurrences: 451
# Primary Type: corner, Secondary Type: loss, Occurrences: 489
# Primary Type: corner, Secondary Type: shot_assist, Occurrences: 524
# Primary Type: corner, Secondary Type: assist, Occurrences: 26
# Primary Type: corner, Secondary Type: second_assist, Occurrences: 10
# Primary Type: corner, Secondary Type: opportunity, Occurrences: 15
# Primary Type: corner, Secondary Type: shot, Occurrences: 2
# Primary Type: corner, Secondary Type: carry, Occurrences: 11
# Primary Type: corner, Secondary Type: third_assist, Occurrences: 5
# Primary Type: corner, Secondary Type: progressive_run, Occurrences: 1
# Primary Type: infraction, Secondary Type: foul, Occurrences: 7068
# Primary Type: infraction, Secondary Type: yellow_card, Occurrences: 1290
# Primary Type: infraction, Secondary Type: penalty_foul, Occurrences: 106
# Primary Type: infraction, Secondary Type: red_card, Occurrences: 54
# Primary Type: throw_in, Secondary Type: loss, Occurrences: 976
# Primary Type: throw_in, Secondary Type: shot_assist, Occurrences: 46
# Primary Type: throw_in, Secondary Type: progressive_run, Occurrences: 6
# Primary Type: throw_in, Secondary Type: carry, Occurrences: 101
# Primary Type: throw_in, Secondary Type: third_assist, Occurrences: 3
# Primary Type: throw_in, Secondary Type: second_assist, Occurrences: 1
# Primary Type: interception, Secondary Type: loss, Occurrences: 6157
# Primary Type: interception, Secondary Type: recovery, Occurrences: 11248
# Primary Type: interception, Secondary Type: counterpressing_recovery, Occurrences: 3863
# Primary Type: interception, Secondary Type: lateral_pass, Occurrences: 1648
# Primary Type: interception, Secondary Type: pass, Occurrences: 7522
# Primary Type: interception, Secondary Type: short_or_medium_pass, Occurrences: 6757
# Primary Type: interception, Secondary Type: under_pressure, Occurrences: 67
# Primary Type: interception, Secondary Type: forward_pass, Occurrences: 3910
# Primary Type: interception, Secondary Type: back_pass, Occurrences: 658
# Primary Type: interception, Secondary Type: shot_block, Occurrences: 1829
# Primary Type: interception, Secondary Type: head_pass, Occurrences: 4974
# Primary Type: interception, Secondary Type: long_pass, Occurrences: 757
# Primary Type: interception, Secondary Type: progressive_pass, Occurrences: 1750
# Primary Type: interception, Secondary Type: pass_to_final_third, Occurrences: 753
# Primary Type: interception, Secondary Type: touch_in_box, Occurrences: 193
# Primary Type: interception, Secondary Type: pass_to_penalty_area, Occurrences: 99
# Primary Type: interception, Secondary Type: carry, Occurrences: 872
# Primary Type: interception, Secondary Type: hand_pass, Occurrences: 236
# Primary Type: interception, Secondary Type: progressive_run, Occurrences: 127
# Primary Type: interception, Secondary Type: acceleration, Occurrences: 137
# Primary Type: interception, Secondary Type: smart_pass, Occurrences: 5
# Primary Type: interception, Secondary Type: through_pass, Occurrences: 35
# Primary Type: interception, Secondary Type: deep_completion, Occurrences: 41
# Primary Type: interception, Secondary Type: shot_assist, Occurrences: 33
# Primary Type: interception, Secondary Type: second_assist, Occurrences: 4
# Primary Type: interception, Secondary Type: key_pass, Occurrences: 15
# Primary Type: interception, Secondary Type: cross, Occurrences: 9
# Primary Type: interception, Secondary Type: cross_blocked, Occurrences: 2
# Primary Type: interception, Secondary Type: third_assist, Occurrences: 3
# Primary Type: interception, Secondary Type: assist, Occurrences: 5
# Primary Type: interception, Secondary Type: deep_completed_cross, Occurrences: 1
# Primary Type: shot_against, Secondary Type: conceded_goal, Occurrences: 762
# Primary Type: shot_against, Secondary Type: save, Occurrences: 1720
# Primary Type: shot_against, Secondary Type: save_with_reflex, Occurrences: 1055
# Primary Type: shot_against, Secondary Type: penalty_conceded_goal, Occurrences: 80
# Primary Type: shot_against, Secondary Type: penalty_save, Occurrences: 15
# Primary Type: free_kick, Secondary Type: free_kick_cross, Occurrences: 890
# Primary Type: free_kick, Secondary Type: free_kick_shot, Occurrences: 265
# Primary Type: free_kick, Secondary Type: opportunity, Occurrences: 148
# Primary Type: free_kick, Secondary Type: shot, Occurrences: 265
# Primary Type: free_kick, Secondary Type: shot_assist, Occurrences: 163
# Primary Type: free_kick, Secondary Type: carry, Occurrences: 37
# Primary Type: free_kick, Secondary Type: third_assist, Occurrences: 3
# Primary Type: free_kick, Secondary Type: assist, Occurrences: 19
# Primary Type: free_kick, Secondary Type: progressive_run, Occurrences: 3
# Primary Type: free_kick, Secondary Type: goal, Occurrences: 12
# Primary Type: free_kick, Secondary Type: second_assist, Occurrences: 3
# Primary Type: acceleration, Secondary Type: progressive_run, Occurrences: 1744
# Primary Type: acceleration, Secondary Type: carry, Occurrences: 2047
# Primary Type: acceleration, Secondary Type: linkup_play, Occurrences: 45
# Primary Type: acceleration, Secondary Type: third_assist, Occurrences: 2
# Primary Type: goalkeeper_exit, Secondary Type: carry, Occurrences: 58
# Primary Type: goal_kick, Secondary Type: loss, Occurrences: 254
# Primary Type: goal_kick, Secondary Type: carry, Occurrences: 53
# Primary Type: goal_kick, Secondary Type: second_assist, Occurrences: 1
# Primary Type: penalty, Secondary Type: goal, Occurrences: 80
# Primary Type: penalty, Secondary Type: penalty_goal, Occurrences: 80
# Primary Type: penalty, Secondary Type: shot, Occurrences: 106
# Primary Type: fairplay, Secondary Type: loss, Occurrences: 153
# Primary Type: fairplay, Secondary Type: interception, Occurrences: 2
# Primary Type: fairplay, Secondary Type: hand_pass, Occurrences: 7
# Primary Type: fairplay, Secondary Type: recovery, Occurrences: 3
# Primary Type: own_goal, Secondary Type: interception, Occurrences: 16
# Primary Type: own_goal, Secondary Type: back_pass, Occurrences: 2
# Primary Type: own_goal, Secondary Type: pass, Occurrences: 3
# Primary Type: own_goal, Secondary Type: short_or_medium_pass, Occurrences: 3
# Primary Type: own_goal, Secondary Type: under_pressure, Occurrences: 1
# Primary Type: own_goal, Secondary Type: recovery, Occurrences: 10
# Primary Type: own_goal, Secondary Type: head_pass, Occurrences: 2
# Primary Type: own_goal, Secondary Type: counterpressing_recovery, Occurrences: 2
# Primary Type: own_goal, Secondary Type: shot_block, Occurrences: 5

# %%
# Initialize an empty list to store tuples of (primary_type, secondary_type)
expanded_rows = []

# Iterate over each row in the DataFrame
for index, row in df.drop_duplicates(subset=['primary_type', 'secondary_types']).iterrows():
    primary = row['primary_type']
    secondary_types = row['secondary_types']
    
    # Check if secondary_types is NaN
    if pd.notna(secondary_types):
        secondary_list = secondary_types.split(',')
        for secondary in secondary_list:
            expanded_rows.append((primary, secondary.strip()))
    else:
        expanded_rows.append((primary, None))  # Handle NaN case

# Create a new DataFrame from the expanded rows
expanded_df = pd.DataFrame(expanded_rows, columns=['primary_type', 'secondary_type'])

# Get the counts of secondary types per primary type
counts_per_primary_type = expanded_df.groupby('primary_type')['secondary_type'].value_counts().reset_index(name='count')

# Calculate total counts per primary type for each secondary type
total_counts_per_primary_type = counts_per_primary_type.groupby('primary_type')['count'].sum().reset_index(name='total_count')

# Merge to get the total counts per primary type
counts_per_primary_type = pd.merge(counts_per_primary_type, total_counts_per_primary_type, on='primary_type')

# Calculate percentages
counts_per_primary_type['percentage'] = counts_per_primary_type['count'] / counts_per_primary_type['total_count']

# Initialize list to store conditional percentages
conditional_percentages = []

# Iterate over each primary type
for primary_type in expanded_df['primary_type'].unique():
    subset_df = expanded_df[expanded_df['primary_type'] == primary_type]
    secondary_types = subset_df['secondary_type'].unique()
    
    # Calculate total occurrences of each secondary type in this primary type
    total_counts = subset_df['secondary_type'].value_counts().reset_index(name='total_count')
    total_counts.rename(columns={'index': 'secondary_type', 'total_count': 'total_count_secondary_type'}, inplace=True)
    
    # Iterate over combinations of secondary types
    for s1, s2 in combinations(secondary_types, 2):
        s1_count = subset_df[subset_df['secondary_type'] == s1].shape[0]
        s2_count = subset_df[subset_df['secondary_type'] == s2].shape[0]
        common_count = subset_df[(subset_df['secondary_type'] == s1) & (subset_df['secondary_type'] == s2)].shape[0]
        
        # Calculate conditional percentage
        if s1_count > 0:
            total_count_s1 = total_counts.loc[total_counts['secondary_type'] == s1, 'total_count_secondary_type'].values[0]
            percentage = common_count / total_count_s1
            conditional_percentages.append((primary_type, s1, s2, percentage))
        
        if s2_count > 0 and s1 != s2:
            total_count_s2 = total_counts.loc[total_counts['secondary_type'] == s2, 'total_count_secondary_type'].values[0]
            percentage = common_count / total_count_s2
            conditional_percentages.append((primary_type, s2, s1, percentage))

# Create DataFrame for conditional percentages
conditional_df = pd.DataFrame(conditional_percentages, columns=['primary_type', 'secondary_type1', 'secondary_type2', 'conditional_percentage'])

# Merge with the main result DataFrame
final_result = pd.merge(counts_per_primary_type, conditional_df, left_on=['primary_type', 'secondary_type'], right_on=['primary_type', 'secondary_type1'])

# Drop unnecessary columns and sort
final_result = final_result[['primary_type', 'secondary_type', 'count', 'percentage', 'secondary_type2', 'conditional_percentage']]
final_result.sort_values(by=['primary_type', 'secondary_type', 'secondary_type2'], inplace=True)

print(final_result)
# Out:
#       primary_type  secondary_type  count  percentage  secondary_type2  \
# 2     acceleration           carry      5    0.384615      linkup_play
# 0     acceleration           carry      5    0.384615  progressive_run
# 3     acceleration           carry      5    0.384615     third_assist
# 1     acceleration           carry      5    0.384615             None
# 5     acceleration     linkup_play      3    0.230769            carry
# ...            ...             ...    ...         ...              ...
# 2777         touch  under_pressure      6    0.120000  progressive_run
# 2780         touch  under_pressure      6    0.120000    second_assist
# 2781         touch  under_pressure      6    0.120000     third_assist
# 2775         touch  under_pressure      6    0.120000     touch_in_box
# 2776         touch  under_pressure      6    0.120000             None
#
#       conditional_percentage
# 2                        0.0
# 0                        0.0
# 3                        0.0
# 1                        0.0
# 5                        0.0
# ...                      ...
# 2777                     0.0
# 2780                     0.0
# 2781                     0.0
# 2775                     0.0
# 2776                     0.0
#
# [2828 rows x 6 columns]
